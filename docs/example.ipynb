# %% [markdown]
# # Example usage
#
# To use `pythoshop` in a project:

# %% [markdown]
# ## Imports

# %%
from pythoshop.adjust_brightness import adjust_brightness
from pythoshop.resize_image import resize_image
from pythoshop.apply_filter import apply_filter
from pythoshop.transform_image import transform_image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# ## adjust_brightness
#
# This function changes the brightness of an input image by a specified factor. The factor can be positive to increase brightness or negative to decrease it. The brightness change is applied uniformly to all pixels of the image. The brightness_factor can be int or float, corresponding to abosulte change or percentage change

# %% [markdown]
# ### Before change

# %%
img = mpimg.imread("../tests/test_img_1.png")
plt.imshow(img)
plt.axis('off')  # Turn off axis numbers and labels
plt.show()

# %% [markdown]
# ### After change

# %%
adjust_brightness("../tests/test_img_1.png", 0.5)

# %%
img = mpimg.imread("../tests/test_img_1_brightness_changed.png")
plt.imshow(img)
plt.axis('off')  # Turn off axis numbers and labels
plt.show()

# %% [markdown]
# ## resize_image
#  This section demonstrates three use cases of the resize_image function: cropping, maintaining aspect ratio, and adding borders. It also displays the original and resized images side by side for comparison.

# %%
# Define example image path
input_path = "../tests/mds_logo.png"

# Example 1: Resize image with cropping
resize_image(input_path, height=150, width=150, method='crop')

# Example 2: Resize image maintaining aspect ratio
resize_image(input_path, height=180, width=180, method='maintain_aspect_ratio')

# Example 3: Resize image with added borders
resize_image(input_path, height=50, width=50, method='add_borders')

# Display the original and resized images
original_img = plt.imread(input_path)
resized_img = plt.imread(f"{input_path[:-4]}_res_img.png")

# Plot original image
print("The Original Image")
plt.subplot(1, 2, 1)
plt.imshow(original_img)
plt.title("Original Image")
plt.axis('off')
# Out:
# Initial image dimensions: (200, 200, 3)
# Resized image saved as: ../tests/mds_logo_res_img.png
# Resize Image Dimensions:  (150, 150, 4)
# Initial image dimensions: (200, 200, 3)
# Resized image saved as: ../tests/mds_logo_res_img.png
# Resize Image Dimensions:  (180, 180, 4)
# Initial image dimensions: (200, 200, 3)
# Resized image saved as: ../tests/mds_logo_res_img.png
# Resize Image Dimensions:  (50, 50, 4)
# The Original Image
# (-0.5, 199.5, 199.5, -0.5)

# %% [markdown]
# ## apply_filter
# This function applies a colored filter on the original image. Users can choose from `red`, `blue`, `gray`, and `sepia` and adjust opacity from 0.5 to 1.0. Once the function runs successully, it saves the image with filter applied under the same file path with `_filter_img` subscript added.

# %% [markdown]
# ### Before Change

# %%
img_path = "../tests/test_img_1.png"
img = mpimg.imread(img_path)
plt.imshow(img)
plt.axis('off')  # Turn off axis numbers and labels
plt.show()

# %% [markdown]
# ### After Change

# %%
apply_filter(img_path, "red", 0.8)

# %% [markdown]
# ## transform_image

# %% [markdown]
# ### Before Change

# %%
img_path = "../tests/test_img_1.png"
img = mpimg.imread(img_path)
plt.imshow(img)
plt.axis('off')  # Turn off axis numbers and labels
plt.show()

# %% [markdown]
# ## Rotate

# %%
transform_image(img_path, method = "rotate", direction = "clockwise")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 transform_image(img_path, method = "rotate", direction = "clockwise")
#
# File ~/Desktop/UBC_Coursework/DSCI524/Pythoshop/src/pythoshop/transform_image.py:71, in transform_image(image_path, method, direction)
#      68 plt.show()
#      70 output_path = image_path.rsplit('.', 1)[0] + "_trns_img.png"
# ---> 71 mpimg.imsave(output_path, new_image, format = 'png')
#      73 print(f"Transformed image saved as {output_path}")
#
# File ~/miniconda3/envs/pythoshop/lib/python3.11/site-packages/matplotlib/image.py:1624, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1622     pil_kwargs = pil_kwargs.copy()
#    1623 pil_shape = (rgba.shape[1], rgba.shape[0])
# -> 1624 image = PIL.Image.frombuffer(
#    1625     "RGBA", pil_shape, rgba, "raw", "RGBA", 0, 1)
#    1626 if format == "png":
#    1627     # Only use the metadata kwarg if pnginfo is not set, because the
#    1628     # semantics of duplicate keys in pnginfo is unclear.
#    1629     if "pnginfo" in pil_kwargs:
#
# File ~/miniconda3/envs/pythoshop/lib/python3.11/site-packages/PIL/Image.py:3029, in frombuffer(mode, size, data, decoder_name, *args)
#    3027 if args[0] in _MAPMODES:
#    3028     im = new(mode, (0, 0))
# -> 3029     im = im._new(core.map_buffer(data, size, decoder_name, 0, args))
#    3030     if mode == "P":
#    3031         from . import ImagePalette
#
# ValueError: ndarray is not C-contiguous

# %%
transform_image(img_path, method = "rotate", direction = "clockwise")
output_img = plt.imread(f'{img_path[:-4]}_trns_img.png')
plt.show(output_img)
